# %% [markdown]
# # Pass4Analysis

# %% [markdown]
# This is a guide on how to navigate the Pass 4 analysis already done

# %% [markdown]
# First, log in to pa-pub and fiesta
#
# You will see a directory called J2019Pass4
# Inside, there are more directories labeled:
#
#     - DataJ2019Pass4
#     - ModelJ2019Pass4
#     - PastAttempts
#     - ResidualsJ2019Pass4

# %% [markdown]
# Past Attempts contains all the files not used in the final analysis

# %% [markdown]
# ## Data Files
#
# The following directories are where you can find the data files are a part of the HAWC Collaboration's Pass 4 Data files.
#
# maptree: /data/scratch/userspace/kmalone/datasets/energy/maps/combined/dataset-ch103-ch755/rejiggered-files/maptree-ch103-ch755.root
#
# response file: /lustre/hawcz01/hawcroot/maps/GP-maps-startChunk103-stopChunk603/countsmaps/detRes-GP-allDecs.root

# %% [markdown]
# ## Convert maptree and detector response file to .hdf5 files
#
# This is the step that applies the model:
#
# Use J2019_fit_logparabola.py to generate .hdf5 files for the model and the residual
#
# Originally done on the local computer
#
# use scp to copy the .hdf5 files to fiesta

# %% [markdown]
# ## .hdf5 files to fits files
#
# Use script hal_hdf5_to_fits.py to convert .hdf5 files to fits files
# --output adds a prefix to the fits files
#
# (new_hal) [elainen@fiesta ModelandResidualsJ2019Pass4]$ python hal_hdf5_to_fits.py --input test_model.hdf5
#
# [WARNING ] The naima package is not available. Models that depend on it will not be available
# [WARNING ] The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it will not be available.
# [WARNING ] The ebltable package is not available. Models that depend on it will not be available
# [INFO    ] Starting 3ML!
# [WARNING ] ROOT minimizer not available
# [WARNING ] The cthreeML package is not installed. You will not be able to use plugins which require the C/C++ interface (currently HAWC)
# [WARNING ] Could not import plugin HAWCLike.py. Do you have the relative instrument software installed and configured?
# [WARNING ] Could not import plugin FermiLATLike.py. Do you have the relative instrument software installed and configured?
# [WARNING ] No fermitools installed
# [WARNING ] Env. variable OMP_NUM_THREADS is not set. Please set it to 1 for optimal performances in 3ML
# [WARNING ] Env. variable MKL_NUM_THREADS is not set. Please set it to 1 for optimal performances in 3ML
# [WARNING ] Env. variable NUMEXPR_NUM_THREADS is not set. Please set it to 1 for optimal performances in 3ML
# [WARNING ] You did not provide any ROI but the map tree test_model.hdf5 contains only data within the ROI HealpixConeROI: Center (R.A., Dec) = (304.920, 36.760), data radius = 3.000 deg, model radius: 8.000 deg. Only those will be used.
# WARNING: VerifyWarning: Keyword name 'MAPFILETYPE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# File Written: map_bin1c.fits.gz
# File Written: map_bin1d.fits.gz
# File Written: map_bin1e.fits.gz
# File Written: map_bin2c.fits.gz
# File Written: map_bin2d.fits.gz
# File Written: map_bin2e.fits.gz
# File Written: map_bin3c.fits.gz
# File Written: map_bin3d.fits.gz
# File Written: map_bin3e.fits.gz
# File Written: map_bin3f.fits.gz
# File Written: map_bin4c.fits.gz
# File Written: map_bin4d.fits.gz
# File Written: map_bin4e.fits.gz
# File Written: map_bin4f.fits.gz
# File Written: map_bin4g.fits.gz
# File Written: map_bin5d.fits.gz
# File Written: map_bin5e.fits.gz
# File Written: map_bin5f.fits.gz
# File Written: map_bin5g.fits.gz
# File Written: map_bin5h.fits.gz
# File Written: map_bin6d.fits.gz
# File Written: map_bin6e.fits.gz
# File Written: map_bin6f.fits.gz
# File Written: map_bin6g.fits.gz
# File Written: map_bin6h.fits.gz
# File Written: map_bin7f.fits.gz
# File Written: map_bin7g.fits.gz
# File Written: map_bin7h.fits.gz
# File Written: map_bin7i.fits.gz
# File Written: map_bin8f.fits.gz
# File Written: map_bin8g.fits.gz
# File Written: map_bin8h.fits.gz
# File Written: map_bin8i.fits.gz
# File Written: map_bin8j.fits.gz
# File Written: map_bin9g.fits.gz
# File Written: map_bin9h.fits.gz
# File Written: map_bin9i.fits.gz
# File Written: map_bin9j.fits.gz
# File Written: map_bin9k.fits.gz
# File Written: map_bin9l.fits.gz
#
#
# (new_hal) [elainen@fiesta ModelandResidualsJ2019Pass4]$ python hal_hdf5_to_fits.py --input test_residual.hdf5 --output Residual
#
# [WARNING ] The naima package is not available. Models that depend on it will not be available
# [WARNING ] The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it will not be available.
# [WARNING ] The ebltable package is not available. Models that depend on it will not be available
# [INFO    ] Starting 3ML!
# [WARNING ] ROOT minimizer not available
# [WARNING ] The cthreeML package is not installed. You will not be able to use plugins which require the C/C++ interface (currently HAWC)
# [WARNING ] Could not import plugin HAWCLike.py. Do you have the relative instrument software installed and configured?
# [WARNING ] Could not import plugin FermiLATLike.py. Do you have the relative instrument software installed and configured?
# [WARNING ] No fermitools installed
# [WARNING ] Env. variable OMP_NUM_THREADS is not set. Please set it to 1 for optimal performances in 3ML
# [WARNING ] Env. variable MKL_NUM_THREADS is not set. Please set it to 1 for optimal performances in 3ML
# [WARNING ] Env. variable NUMEXPR_NUM_THREADS is not set. Please set it to 1 for optimal performances in 3ML
# [WARNING ] You did not provide any ROI but the map tree test_residual.hdf5 contains only data within the ROI HealpixConeROI: Center (R.A., Dec) = (304.920, 36.760), data radius = 3.000 deg, model radius: 8.000 deg. Only those will be used.
# WARNING: VerifyWarning: Keyword name 'MAPFILETYPE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# File Written: Residual_bin1c.fits.gz
# File Written: Residual_bin1d.fits.gz
# File Written: Residual_bin1e.fits.gz
# File Written: Residual_bin2c.fits.gz
# File Written: Residual_bin2d.fits.gz
# File Written: Residual_bin2e.fits.gz
# File Written: Residual_bin3c.fits.gz
# File Written: Residual_bin3d.fits.gz
# File Written: Residual_bin3e.fits.gz
# File Written: Residual_bin3f.fits.gz
# File Written: Residual_bin4c.fits.gz
# File Written: Residual_bin4d.fits.gz
# File Written: Residual_bin4e.fits.gz
# File Written: Residual_bin4f.fits.gz
# File Written: Residual_bin4g.fits.gz
# File Written: Residual_bin5d.fits.gz
# File Written: Residual_bin5e.fits.gz
# File Written: Residual_bin5f.fits.gz
# File Written: Residual_bin5g.fits.gz
# File Written: Residual_bin5h.fits.gz
# File Written: Residual_bin6d.fits.gz
# File Written: Residual_bin6e.fits.gz
# File Written: Residual_bin6f.fits.gz
# File Written: Residual_bin6g.fits.gz
# File Written: Residual_bin6h.fits.gz
# File Written: Residual_bin7f.fits.gz
# File Written: Residual_bin7g.fits.gz
# File Written: Residual_bin7h.fits.gz
# File Written: Residual_bin7i.fits.gz
# File Written: Residual_bin8f.fits.gz
# File Written: Residual_bin8g.fits.gz
# File Written: Residual_bin8h.fits.gz
# File Written: Residual_bin8i.fits.gz
# File Written: Residual_bin8j.fits.gz
# File Written: Residual_bin9g.fits.gz
# File Written: Residual_bin9h.fits.gz
# File Written: Residual_bin9i.fits.gz
# File Written: Residual_bin9j.fits.gz
# File Written: Residual_bin9k.fits.gz
# File Written: Residual_bin9l.fits.gz

# %% [markdown]
# ## Condense fit files to one
#
#     - Here, you can control the window size
#     - For Residuals, in order to pull up a correct 1D significance map, make sure to add -negFlux and -negSignif markers
#
# (aerie-gfx) [elainen@fiesta ModelandResidualsJ2019Pass4]$ aerie-apps-HealpixSigFluxMap -i Residual_bin1c.fits.gz Residual_bin1d.fits.gz Residual_bin1e.fits.gz Residual_bin2c.fits.gz Residual_bin2d.fits.gz Residual_bin2e.fits.gz Residual_bin3c.fits.gz Residual_bin3d.fits.gz Residual_bin3e.fits.gz Residual_bin3f.fits.gz Residual_bin4c.fits.gz Residual_bin4d.fits.gz Residual_bin4e.fits.gz Residual_bin4f.fits.gz Residual_bin4g.fits.gz Residual_bin5d.fits.gz Residual_bin5e.fits.gz Residual_bin5f.fits.gz Residual_bin5g.fits.gz Residual_bin5h.fits.gz Residual_bin6d.fits.gz Residual_bin6e.fits.gz Residual_bin6f.fits.gz Residual_bin6g.fits.gz Residual_bin6h.fits.gz Residual_bin7f.fits.gz Residual_bin7g.fits.gz Residual_bin7h.fits.gz Residual_bin7i.fits.gz Residual_bin8f.fits.gz Residual_bin8g.fits.gz Residual_bin8h.fits.gz Residual_bin8i.fits.gz Residual_bin8j.fits.gz Residual_bin9g.fits.gz Residual_bin9h.fits.gz Residual_bin9i.fits.gz Residual_bin9j.fits.gz Residual_bin9k.fits.gz Residual_bin9l.fits.gz --index 2.5 -o DataHAWCJ2019.fits.gz -d detRes-GP-allDecs.root -b 1c 1d 1e 2c 2d 2e 3c 3d 3e 3f 4c 4d 4e 4f 4g 5d 5e 5f 5g 5h 6d 6e 6f 6g 6h 7f 7g 7h 7i 8f 8g 8h 8i 8j 9g 9h 9i 9j 9k 9l --window 304.92 36.76 5 5 --negFlux --negSignif --pivot 7 --nthreads 5
#
# Make a Residual Map with a bigger window:
#
# (aerie-gfx) [elainen@fiesta ModelandResidualsJ2019Pass4]$ aerie-apps-HealpixSigFluxMap -i Residual_bin1c.fits.gz Residual_bin1d.fits.gz Residual_bin1e.fits.gz Residual_bin2c.fits.gz Residual_bin2d.fits.gz Residual_bin2e.fits.gz Residual_bin3c.fits.gz Residual_bin3d.fits.gz Residual_bin3e.fits.gz Residual_bin3f.fits.gz Residual_bin4c.fits.gz Residual_bin4d.fits.gz Residual_bin4e.fits.gz Residual_bin4f.fits.gz Residual_bin4g.fits.gz Residual_bin5d.fits.gz Residual_bin5e.fits.gz Residual_bin5f.fits.gz Residual_bin5g.fits.gz Residual_bin5h.fits.gz Residual_bin6d.fits.gz Residual_bin6e.fits.gz Residual_bin6f.fits.gz Residual_bin6g.fits.gz Residual_bin6h.fits.gz Residual_bin7f.fits.gz Residual_bin7g.fits.gz Residual_bin7h.fits.gz Residual_bin7i.fits.gz Residual_bin8f.fits.gz Residual_bin8g.fits.gz Residual_bin8h.fits.gz Residual_bin8i.fits.gz Residual_bin8j.fits.gz Residual_bin9g.fits.gz Residual_bin9h.fits.gz Residual_bin9i.fits.gz Residual_bin9j.fits.gz Residual_bin9k.fits.gz Residual_bin9l.fits.gz --index 2.5 -o ResidualNegSignifwindow10.fits.gz -d detRes-GP-allDecs.root -b 1c 1d 1e 2c 2d 2e 3c 3d 3e 3f 4c 4d 4e 4f 4g 5d 5e 5f 5g 5h 6d 6e 6f 6g 6h 7f 7g 7h 7i 8f 8g 8h 8i 8j 9g 9h 9i 9j 9k 9l --window 304.92 36.76 10 10  --negFlux --negSignif --pivot 7 --nthreads 5
# INFO [HealpixSigFluxMap.cc, main:178]: Opening maps...
# INFO [HealpixSigFluxMap.cc, main:236]: Processing detector response...
# INFO [TF1PointSource.cc, describe:140]:
# TF1 Point Source:
#   Name:          ps
#   R.A. (J2000):  80 deg
#   Dec. (J2000):  20 deg
# INFO [Func1.h, PrintOut:94]:
# Function: [0]*pow(x/[3],-[1])*exp(-x/[2]):
#   (Par 0) Norm: 1 +/- 0.5
#   (Par 1) Index: 2.5 +/- 0.1
#   (Par 2) CutOff: 1.79769e+308 +/- 8.98847e+307
#   (Par 3) Pivot: 7 +/- 0
# INFO [HealpixSigFluxMap.cc, main:414]: Setting window...
# INFO [HealpixSigFluxMap.cc, main:572]: Computing significance...
# INFO [HealpixSigFluxMap.cc, main:634]: 0%
# INFO [HealpixSigFluxMap.cc, main:647]: 1%
# INFO [HealpixSigFluxMap.cc, main:647]: 2%
# INFO [HealpixSigFluxMap.cc, main:647]: 3%
# INFO [HealpixSigFluxMap.cc, main:647]: 4%
# INFO [HealpixSigFluxMap.cc, main:647]: 5%
# INFO [HealpixSigFluxMap.cc, main:647]: 6%
# INFO [HealpixSigFluxMap.cc, main:647]: 7%
# INFO [HealpixSigFluxMap.cc, main:647]: 8%
# INFO [HealpixSigFluxMap.cc, main:647]: 9%
# INFO [HealpixSigFluxMap.cc, main:647]: 10%
# INFO [HealpixSigFluxMap.cc, main:647]: 11%
# INFO [HealpixSigFluxMap.cc, main:647]: 12%
# INFO [HealpixSigFluxMap.cc, main:647]: 13%
# INFO [HealpixSigFluxMap.cc, main:647]: 14%
# INFO [HealpixSigFluxMap.cc, main:647]: 15%
# INFO [HealpixSigFluxMap.cc, main:647]: 16%
# INFO [HealpixSigFluxMap.cc, main:647]: 17%
# INFO [HealpixSigFluxMap.cc, main:647]: 18%
# INFO [HealpixSigFluxMap.cc, main:647]: 19%
# INFO [HealpixSigFluxMap.cc, main:647]: 20%
# INFO [HealpixSigFluxMap.cc, main:647]: 21%
# INFO [HealpixSigFluxMap.cc, main:647]: 22%
# INFO [HealpixSigFluxMap.cc, main:647]: 23%
# INFO [HealpixSigFluxMap.cc, main:647]: 24%
# INFO [HealpixSigFluxMap.cc, main:647]: 25%
# INFO [HealpixSigFluxMap.cc, main:647]: 26%
# INFO [HealpixSigFluxMap.cc, main:647]: 27%
# INFO [HealpixSigFluxMap.cc, main:647]: 28%
# INFO [HealpixSigFluxMap.cc, main:647]: 29%
# INFO [HealpixSigFluxMap.cc, main:647]: 30%
# INFO [HealpixSigFluxMap.cc, main:647]: 31%
# INFO [HealpixSigFluxMap.cc, main:647]: 32%
# INFO [HealpixSigFluxMap.cc, main:647]: 33%
# INFO [HealpixSigFluxMap.cc, main:647]: 34%
# INFO [HealpixSigFluxMap.cc, main:647]: 35%
# INFO [HealpixSigFluxMap.cc, main:647]: 36%
# INFO [HealpixSigFluxMap.cc, main:647]: 37%
# INFO [HealpixSigFluxMap.cc, main:647]: 38%
# INFO [HealpixSigFluxMap.cc, main:647]: 39%
# INFO [HealpixSigFluxMap.cc, main:647]: 40%
# INFO [HealpixSigFluxMap.cc, main:647]: 41%
# INFO [HealpixSigFluxMap.cc, main:647]: 42%
# INFO [HealpixSigFluxMap.cc, main:647]: 43%
# INFO [HealpixSigFluxMap.cc, main:647]: 44%
# INFO [HealpixSigFluxMap.cc, main:647]: 45%
# INFO [HealpixSigFluxMap.cc, main:647]: 46%
# INFO [HealpixSigFluxMap.cc, main:647]: 47%
# INFO [HealpixSigFluxMap.cc, main:647]: 48%
# INFO [HealpixSigFluxMap.cc, main:647]: 49%
# INFO [HealpixSigFluxMap.cc, main:647]: 50%
# INFO [HealpixSigFluxMap.cc, main:647]: 51%
# INFO [HealpixSigFluxMap.cc, main:647]: 52%
# INFO [HealpixSigFluxMap.cc, main:647]: 53%
# INFO [HealpixSigFluxMap.cc, main:647]: 54%
# INFO [HealpixSigFluxMap.cc, main:647]: 55%
# INFO [HealpixSigFluxMap.cc, main:647]: 56%
# INFO [HealpixSigFluxMap.cc, main:647]: 57%
# INFO [HealpixSigFluxMap.cc, main:647]: 58%
# INFO [HealpixSigFluxMap.cc, main:647]: 59%
# INFO [HealpixSigFluxMap.cc, main:647]: 60%
# INFO [HealpixSigFluxMap.cc, main:647]: 61%
# INFO [HealpixSigFluxMap.cc, main:647]: 62%
# INFO [HealpixSigFluxMap.cc, main:647]: 63%
# INFO [HealpixSigFluxMap.cc, main:647]: 64%
# INFO [HealpixSigFluxMap.cc, main:647]: 65%
# INFO [HealpixSigFluxMap.cc, main:647]: 66%
# INFO [HealpixSigFluxMap.cc, main:647]: 67%
# INFO [HealpixSigFluxMap.cc, main:647]: 68%
# INFO [HealpixSigFluxMap.cc, main:647]: 69%
# INFO [HealpixSigFluxMap.cc, main:647]: 70%
# INFO [HealpixSigFluxMap.cc, main:647]: 71%
# INFO [HealpixSigFluxMap.cc, main:647]: 72%
# INFO [HealpixSigFluxMap.cc, main:647]: 73%
# INFO [HealpixSigFluxMap.cc, main:647]: 74%
# INFO [HealpixSigFluxMap.cc, main:647]: 75%
# INFO [HealpixSigFluxMap.cc, main:647]: 76%
# INFO [HealpixSigFluxMap.cc, main:647]: 77%
# INFO [HealpixSigFluxMap.cc, main:647]: 78%
# INFO [HealpixSigFluxMap.cc, main:647]: 79%
# INFO [HealpixSigFluxMap.cc, main:647]: 80%
# INFO [HealpixSigFluxMap.cc, main:647]: 81%
# INFO [HealpixSigFluxMap.cc, main:647]: 82%
# INFO [HealpixSigFluxMap.cc, main:647]: 83%
# INFO [HealpixSigFluxMap.cc, main:647]: 84%
# INFO [HealpixSigFluxMap.cc, main:647]: 85%
# INFO [HealpixSigFluxMap.cc, main:647]: 86%
# INFO [HealpixSigFluxMap.cc, main:647]: 87%
# INFO [HealpixSigFluxMap.cc, main:647]: 88%
# INFO [HealpixSigFluxMap.cc, main:647]: 89%
# INFO [HealpixSigFluxMap.cc, main:647]: 90%
# INFO [HealpixSigFluxMap.cc, main:647]: 91%
# INFO [HealpixSigFluxMap.cc, main:647]: 92%
# INFO [HealpixSigFluxMap.cc, main:647]: 93%
# INFO [HealpixSigFluxMap.cc, main:647]: 94%
# INFO [HealpixSigFluxMap.cc, main:647]: 95%
# INFO [HealpixSigFluxMap.cc, main:647]: 96%
# INFO [HealpixSigFluxMap.cc, main:647]: 97%
# INFO [HealpixSigFluxMap.cc, main:647]: 98%
# INFO [HealpixSigFluxMap.cc, main:647]: 99%
# INFO [HealpixSigFluxMap.cc, main:647]: 100%
# INFO [HealpixSigFluxMap.cc, main:867]: Writing file ResidualNegSignifwindow10.fits.gz to disk...
# INFO [HealpixSigFluxMap.cc, main:912]: Elapsed time: 4.38333 min

# %% [markdown]
# ## Convert  residual fits.gz file to histogram .png
#
#
#
# ## Make significance histogram
#
# (aerie-gfx) [elainen@fiesta ModelandResidualsJ2019Pass4]$ makeSignificanceHistogram.py ResidualNegSignifwindow10.fits.gz --includeArea --ra 304.92 --dec 36.76 --binsize 1.0 -s -5 -S 15
